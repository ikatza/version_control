# %% [markdown]
# # <center> Solving ODE with numerical methods

# %% [markdown]
# ## Euler's Method

# %% [markdown]
# Let be
#  $$ \dot{x(t)} = f(x(t),t) $$
# an ODE.
#
# We can discretize the equation in terms of its derivative, obtaining
#  $$ x_{n+1} = x_n + h \ f(x_n,t_n) $$

# %%
function euler(x,f::Function,h)
    return x + h.*f(x)
end
# Out:
# euler (generic function with 2 methods)

# %%
function integrador(x,f::Function,t_f::Real,h=.001)
    T = collect(0:h:t_f)
    X = zeros(length(T),length(x))
    X[1,:] = x
    
    for i in 2:length(T)
        x = euler(x,f,h)
        X[i-1,:] = x
    end
    
    return T, X
end
# Out:
# integrador (generic function with 4 methods)

# %% [markdown]
# ###  Example (Armonic Oscilator)

# %% [markdown]
# El oscilador armónico está dado por
#  $$ \ddot{x} = -\frac{k}{m} x $$
#
# Si $v_x = \dot{x}$, entonces
#  \begin{array}
#   \dot{x} &=& v_x \\
#   \dot{v_x} &=& -\omega^2 x \\
#  \end{array}

# %%
using PyPlot

# %%
function oscillator(X) 
    x, vx = X
    return [vx, -ω^2*x]
end

ω = 1
CI = [3,0.]
t_f = 5
T,X = integrador(CI,oscillator,t_f);

# %%
plot(T,X[:,1])
title("Harmonic Oscillator")
xlabel("t [s]")
ylabel("x [m]");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31e848cd0>)
